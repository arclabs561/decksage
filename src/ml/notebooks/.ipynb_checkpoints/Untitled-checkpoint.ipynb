# %%
import csv
import random
from gensim import corpora
from itertools import islice
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec
from tqdm import tqdm

# %%
class Corpus(object):
    def __iter__(self):
        with open('../../backend/collections.csv') as f:
            for record in csv.reader(f):
                random.shuffle(record)
                yield record

# %%
corpus = Corpus()
for record in islice(corpus, 1):
    print(record)
# Out:
# ['Fall of the Hammer', 'Hammer of Purphoros', "Purphoros's Emissary", 'Mountain', 'Archetype of Aggression', 'Rage of Purphoros', 'Mountain', 'Mountain', 'Mountain', 'Forgeborn Oreads', 'Fall of the Hammer', 'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Mountain', 'Forgestoker Dragon', 'Mountain', 'Mountain', 'Mountain', 'Boulderfall', 'Fated Conflagration', 'Mountain', 'Fall of the Hammer', 'Spawn of Thraxes', 'Mountain', 'Mountain', "Purphoros's Emissary", 'Mountain', 'Forgestoker Dragon', 'Mountain', 'Mountain', 'Archetype of Aggression', 'Ordeal of Purphoros', 'Everflame Eidolon', 'Mountain', 'Purphoros, God of the Forge', 'Ember Swallower', 'Everflame Eidolon', 'Searing Blood', 'Mountain', 'Magma Spray', 'Forgeborn Oreads', 'Scouring Sands', "Purphoros's Emissary", 'Ember Swallower', 'Everflame Eidolon', 'Scouring Sands', 'Forgeborn Oreads', 'Searing Blood', 'Archetype of Aggression', 'Mountain', 'Mountain', 'Mountain', 'Forgeborn Oreads', 'Mountain', 'Ember Swallower', 'Ember Swallower', 'Magma Spray', 'Fall of the Hammer']

# %%
sum((1 for _ in corpus))
# Out:
# 72729

# %%
dictionary = corpora.Dictionary(corpus)

# %%
class Callback(CallbackAny2Vec):
    def __init__(self, epochs):
        self.pbar = tqdm(total=epochs)
    
    def on_epoch_end(self, model):
        self.pbar.update()
        
    def close(self):
        self.pbar.close()
        
    def __enter__(self):
        self.pbar = tqdm(total=epochs)
        return self

    def __exit__(self):
        self.pbar.close()

with Callback() as callback:
    model = Word2Vec(
        sentences=corpus,
        vector_size=128,
        window=60,
        min_count=0,
        workers=-1,
        epochs=100,
        shrink_windows=False,
        callbacks=[callback],
    )

# %%
model.wv.most_similar('Forest')
# Out:
# [('Thornscape Familiar', 0.38638976216316223),
#  ('Kira, Great Glass-Spinner', 0.33599984645843506),
#  ('Mirko Vosk, Mind Drinker', 0.31353914737701416),
#  ('Ghostly Prison', 0.31021007895469666),
#  ('Seed Guardian', 0.30650997161865234),
#  ('Rally the Ancestors', 0.30284151434898376),
#  ('Flames of the Raze-Boar', 0.3010490834712982),
#  ('Keiga, the Tide Star', 0.29782816767692566),
#  ('Artifact Possession', 0.2967875897884369),
#  ('Elvish Handservant', 0.2943800985813141)]
